-- %% [markdown]
-- These files are used by the RepoAssetsSuite
--
-- * SF-Airbnbs is used for testing getting the asset by object_id (tree id)
-- * SF-Airbnbs-resource-id is used for testing getting the asset by resource_id (dashboard UUID)
-- * corrupt-SF-Airbnbs is used for testing that we can successfully clone even with a corrupt file and attempting to export it throws an informative message
